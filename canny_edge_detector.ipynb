# %%
# %load_ext autoreload
# %autoreload 2

# %%
from matplotlib import pyplot as plt
from edge_detector import CannyEdgeDetector

# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = (15.0, 12.0) # Set the default size of images.
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %%
# Compare the original image to its detected edges (on large images, this can take a while to run):

CED = CannyEdgeDetector()
for file_name in ['building.jpg', 'dolphin.jpg', 'shells.jpg']:
    CED.show_image_and_edges(file_name)

# %%
# See all of the intermediate images generated during the Canny edge-detection algorithm:

CED = CannyEdgeDetector()
edges = CED.get_canny_edges('shells.jpg', verbose = True)
